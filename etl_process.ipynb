# %% [markdown]
# ## Proyec

# %%
import pandas as pd

# %%
data_pre = pd.read_csv("Datasets/desaparecidos_colombia_1930_a_2025.csv")
data_pre
# Out:
#             ID Entidad que realiza el registro de la desaparición  \
# 0            1  Instituto Nacional de Medicina Legal y Ciencia...
# 1            2  Instituto Nacional de Medicina Legal y Ciencia...
# 2            3  Instituto Nacional de Medicina Legal y Ciencia...
# 3            4  Instituto Nacional de Medicina Legal y Ciencia...
# 4            5  Instituto Nacional de Medicina Legal y Ciencia...
# ...        ...                                                ...
# 195803  195804       Unidad de Busqueda de Personas Desaparecidas
# 195804  195805       Unidad de Busqueda de Personas Desaparecidas
# 195805  195806       Unidad de Busqueda de Personas Desaparecidas
# 195806  195807       Unidad de Busqueda de Personas Desaparecidas
# 195807  195808       Unidad de Busqueda de Personas Desaparecidas
#
#        Estado de la desaparición Clasificación de la desaparición  \
# 0                   Desaparecido                  Sin información
# ...
